# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
cf = [[312, 29, 11],[209, 27, 35], [22, 2, 2]]

# %%
sn.set(rc={"figure.dpi":300})
sn.heatmap(cf, annot=True, cmap='Blues',fmt='g', xticklabels=['Safe', 'Homophobic', 'Transphobic'], yticklabels=['Safe', 'Homophobic', 'Transphobic']) # font size
# Out:
# <AxesSubplot:>
