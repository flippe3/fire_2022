# %%
import pandas as pd

# %%
eng_train = pd.read_csv("../data/eng_3_train.tsv","\t")
eng_dev = pd.read_csv("../data/eng_3_dev.tsv","\t")

mal_train = pd.read_csv("../data/mal_3_train.csv")
mal_dev = pd.read_csv("../data/mal_3_dev.csv")

tam_train = pd.read_csv("../data/tam_3_train.tsv","\t")
tam_dev = pd.read_csv("../data/tam_3_dev.tsv","\t")

eng_tam_train = pd.read_csv("../data/eng-tam_3_train.tsv","\t")
eng_tam_dev = pd.read_csv("../data/eng-tam_3_dev.tsv","\t")

# %%
tam_train.drop_duplicates(subset='text')
# Out:
#                     category  \
# 0                Transphobic
# 1     Non-anti-LGBT+ content
# 2                Transphobic
# 3     Non-anti-LGBT+ content
# 4     Non-anti-LGBT+ content
# ...                      ...
# 2652  Non-anti-LGBT+ content
# 2653  Non-anti-LGBT+ content
# 2656  Non-anti-LGBT+ content
# 2658  Non-anti-LGBT+ content
# 2660  Non-anti-LGBT+ content
#
#                                                    text  \
# 0     அர்த்தநாரீஸ்வரர் ஆணுமானவர் பெண்ணுமானவர். இது ஒ...
# 1     section377 | ஓரினச்சேர்க்கை நல்லதா கெட்டதா மக்...
# 2     இருக்கிற நாலு பேர் சேர்ந்து அந்த பொறம்போக்கு ச...
# 3     Shanth sha  உடலுறவு இனப்பெருக்கத்திற்கு மட்டும...
# 4                                    ஜீவநதி ப்ரியன்  hi
# ...                                                 ...
# 2652  வெளிநாட்டில் இருக்குதாம் அதனால சரியாதான் இதுக்...
# 2653                Gay அன்பு தாயின் அன்புக்கு நிகரானது
# 2656  Sekarsekar Sekarsekar  ஓத்தால கூட்டிகுடுட பலதந...
# ...

# %%
tam_train_duplicates = 0
for i in eng_tam_train.text:
    for j in eng_tam_dev.text:
        if i == j:
            tam_train_duplicates += 1
            break
print(tam_train_duplicates)
# Out:
# 26

# %%
tam_train_duplicates = len(tam_train.text.duplicated()[tam_train.text.duplicated()==True])
mal_train_duplicates = len(mal_train.text.duplicated()[mal_train.text.duplicated()==True])

# %%
tam_train.drop_duplicates(subset='text')
# Out:
#                     category  \
# 0                Transphobic
# 1     Non-anti-LGBT+ content
# 2                Transphobic
# 3     Non-anti-LGBT+ content
# 4     Non-anti-LGBT+ content
# ...                      ...
# 2652  Non-anti-LGBT+ content
# 2653  Non-anti-LGBT+ content
# 2656  Non-anti-LGBT+ content
# 2658  Non-anti-LGBT+ content
# 2660  Non-anti-LGBT+ content
#
#                                                    text  \
# 0     அர்த்தநாரீஸ்வரர் ஆணுமானவர் பெண்ணுமானவர். இது ஒ...
# 1     section377 | ஓரினச்சேர்க்கை நல்லதா கெட்டதா மக்...
# 2     இருக்கிற நாலு பேர் சேர்ந்து அந்த பொறம்போக்கு ச...
# 3     Shanth sha  உடலுறவு இனப்பெருக்கத்திற்கு மட்டும...
# 4                                    ஜீவநதி ப்ரியன்  hi
# ...                                                 ...
# 2652  வெளிநாட்டில் இருக்குதாம் அதனால சரியாதான் இதுக்...
# 2653                Gay அன்பு தாயின் அன்புக்கு நிகரானது
# 2656  Sekarsekar Sekarsekar  ஓத்தால கூட்டிகுடுட பலதந...
# ...

# %%
f = open('new_eng_tam_train.tsv', 'w')
f.write(f'category\ttext\n')
label_count = 0
for i in eng_tam_train.text.values:
    found = False
    for j in eng_tam_dev.text.values:
        if i == j:
            found = True
    if found == False:
        f.write(eng_tam_train.category.values[label_count] + "\t" + str(i) + '\n')
    label_count += 1

# %%
nt = pd.read_csv('new_eng_tam_train.tsv', '\t')
dup = 0
for i in eng_train.text.values:
    for j in eng_dev.text.values:
        if i == j:
            dup += 1
            break
print(dup)
# Out:
# 0

# %%
nt.category.value_counts()
# Out:
# Non-anti-LGBT+ content    3406
# Homophobic                 311
# Transphobic                112
# Name: category, dtype: int64
