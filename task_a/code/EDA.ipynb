# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tam_train = pd.read_csv("../data/tam_sentiment_train.tsv","\t")
tam_dev = pd.read_csv("../data/tam_sentiment_dev.tsv","\t")

kan_train = pd.read_csv("../data/kan_sentiment_train.tsv","\t")
kan_dev = pd.read_csv("../data/kan_sentiment_dev.tsv","\t")

mal_train = pd.read_csv("../data/Mal_sentiment_train.tsv","\t")
mal_dev = pd.read_csv("../data/Mal_sentiment_dev.tsv","\t")

# %% [markdown]
# ## Tamil

# %%
print(tam_train.category.value_counts())
tam_train.category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# Positive          20069
# unknown_state      5628
# Negative           4271
# Mixed_feelings     4020
# not-Tamil          1667
# Positive              1
# Name: category, dtype: int64
# <AxesSubplot:>

# %%
print(tam_dev.category.value_counts())
tam_dev.category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# Positive          2257
# unknown_state      611
# Negative           480
# Mixed_feelings     438
# not-Tamil          176
# Name: category, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ## Kannada

# %%
print(kan_train.category.value_counts())
kan_train.category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# Positive          2823
# Negative          1188
# not-Kannada        916
# unknown state      711
# Mixed feelings     574
# Name: category, dtype: int64
# <AxesSubplot:>

# %%
print(kan_dev.category.value_counts())
kan_dev.category.value_counts().sort_values().plot(kind='barh')
# Out:
# Positive          321
# Negative          139
# not-Kannada       110
# unknown state      69
# Mixed feelings     52
# Name: category, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ## Malayalam

# %%
print(mal_train.category.value_counts())
mal_train.category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# Positive          6421
# unknown_state     5279
# Negative          2105
# not-malayalam     1157
# Mixed_feelings     926
# Name: category, dtype: int64
# <AxesSubplot:>

# %%
print(mal_dev.category.value_counts())
mal_dev.category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# Positive          706
# unknown_state     580
# Negative          237
# not-malayalam     141
# Mixed_feelings    102
# Name: category, dtype: int64
# <AxesSubplot:>

# %%
import random
id = random.randint(0, len(tam_train))
print(tam_train.text[id])
print(tam_train.category[id])
# Out:
# Dai intha pandya ennada pannitruka athuvum thalaiku equals
# Positive
